# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import json
import pandas

statsDict_Abhideep_Dasgupta1.json
statsDict_Abhideep_Dasgupta2.json
statsDict_Abhideep_Dasgupta3.json
statsDict_.json
statsDict_Chen_Wu1.json
statsDict_.json
statsDict_.json
statsDict_.json
statsDict_.json

# %%
json_data_sanorita=open('./newdata/dict2/dictB/statsDict_sanorita_dey.json')
json_data_nate=open('./newdata/dict2/dictB/statsDict_nate_white.json')
json_data_mylene3=open('./newdata/dict2/dictB/statsDict_mylene_haus3.json')
json_data_mylene1=open('./newdata/dict2/dictB/statsDict_mylene_haus1.json')
json_data_josie=open('./newdata/dict2/dictB/statsDict_josie_geng.json')
json_data_john3=open('./newdata/dict2/dictB/statsDict_john_lee3.json')
json_data_john2=open('./newdata/dict2/dictB/statsDict_john_lee2.json')
json_data_john1=open('./newdata/dict2/dictB/statsDict_john_lee1.json')
json_data_jeongwoo2=open('./newdata/dict2/dictB/statsDict_JeongWoo_Chang2.json')
json_data_jeongwoo1=open('./newdata/dict2/dictB/statsDict_JeongWoo_Chang1.json')
json_data_heroofbutt=open('./newdata/dict2/dictB/statsDict_HeroOfButt.json')
json_data_chris=open('./newdata/dict2/dictB/statsDict_chris_cervantes.json')
json_data_chen2=open('./newdata/dict2/dictB/statsDict_Chen_Wu2.json')
json_data_chen1=open('./newdata/dict2/dictB/statsDict_Chen_Wu1.json')
json_data_abhideep4=open('./newdata/dict2/dictB/statsDict_Abhideep_Dasgupta4.json')
json_data_abhideep3=open('./newdata/dict2/dictB/statsDict_Abhideep_Dasgupta3.json')
json_data_abhideep2=open('./newdata/dict2/dictB/statsDict_Abhideep_Dasgupta2.json')
json_data_abhideep1=open('./newdata/dict2/dictB/statsDict_Abhideep_Dasgupta1.json')

# %%
data_abhideep1 = json.load(json_data_abhideep1)
data_abhideep2 = json.load(json_data_abhideep2)
data_abhideep3 = json.load(json_data_abhideep3)
data_abhideep4 = json.load(json_data_abhideep4)
data_chen1 = json.load(json_data_chen1)
data_chen2 = json.load(json_data_chen2)
data_chris = json.load(json_data_chris)
data_heroofbutt = json.load(json_data_heroofbutt)
data_jeongwoo1 = json.load(json_data_jeongwoo1)
data_jeongwoo2 = json.load(json_data_jeongwoo2)
data_john1 = json.load(json_data_john1)
data_john2 = json.load(json_data_john2)
data_john3 = json.load(json_data_john3)
data_josie = json.load(json_data_josie)
data_mylene1 = json.load(json_data_mylene1)
data_mylene3 = json.load(json_data_mylene3)
data_nate = json.load(json_data_nate)
data_sanorita = json.load(json_data_sanorita)

# %%
df1 = pandas.DataFrame.from_dict(data_sanorita,orient='index')#, dtype=None)
df2 = pandas.DataFrame.from_dict(data_nate,orient='index')#, dtype=None)
df3 = pandas.DataFrame.from_dict(data_mylene1,orient='index')#, dtype=None)
df4 = pandas.DataFrame.from_dict(data_mylene3,orient='index')#, dtype=None)
df5 = pandas.DataFrame.from_dict(data_josie,orient='index')#, dtype=None)
df6 = pandas.DataFrame.from_dict(data_john3,orient='index')#, dtype=None)
df7 = pandas.DataFrame.from_dict(data_john2,orient='index')#, dtype=None)
df8 = pandas.DataFrame.from_dict(data_john1,orient='index')#, dtype=None)
df9 = pandas.DataFrame.from_dict(data_jeongwoo2,orient='index')#, dtype=None)
df10 = pandas.DataFrame.from_dict(data_jeongwoo1,orient='index')#, dtype=None)
df11 = pandas.DataFrame.from_dict(data_heroofbutt,orient='index')#, dtype=None)
df12 = pandas.DataFrame.from_dict(data_chris,orient='index')#, dtype=None)
df13 = pandas.DataFrame.from_dict(data_chen2,orient='index')#, dtype=None)
df14 = pandas.DataFrame.from_dict(data_chen1,orient='index')#, dtype=None)
df15 = pandas.DataFrame.from_dict(data_abhideep4,orient='index')#, dtype=None)
df16 = pandas.DataFrame.from_dict(data_abhideep3,orient='index')#, dtype=None)
df17 = pandas.DataFrame.from_dict(data_abhideep2,orient='index')#, dtype=None)
df18 = pandas.DataFrame.from_dict(data_abhideep1,orient='index')#, dtype=None)

# %%
finaldf = pandas.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18],axis=1)
finaldf.columns = ['sanorita','nate','mylene1','mylene3','josie','john3','john2','john1','jeongwoo2','jeongwoo1','heroofbutt','chris','chen2','chen1','abhideep4','abhideep3','abhideep2','abhideep1']

# %%
finaldf
# Out:
#                                  sanorita    nate mylene1 mylene3   josie  \
# PLAYER AND STATUE ON SAME SQUARE        2       2       0       0       8
# MOVES INTO STATUE                       3       5       0       0       3
# BOTTOM STATUE EDGE OF BOARD            13      22       1       6      10
# MOVES OFF BOARD                        15      11       0       0      61
# TIME IN FIRST HELP SCREEN           40000   18000    6000    1000   37000
# TURNS                                 166     179       1      26     152
# ACTIONS                               283     303       3      39     329
# END GAME                              WIN     WIN   ABORT     WIN   ABORT
# STATUES MOVE ONTO SAME SQUARE           0       5       0       0       1
# TURNCC                                140      45       0      13      63
# HINTS                                   1       1       0       0       2
# TIMESTAMP                          909000  448000   38000   68000  601000
# ...

# %%
dff.mean(axis=1,numeric_only=False)
# Out:
# PLAYER AND STATUE ON SAME SQUARE         1.928571
# MOVES INTO STATUE                        2.500000
# BOTTOM STATUE EDGE OF BOARD             10.428571
# MOVES OFF BOARD                          5.785714
# TIME IN FIRST HELP SCREEN            23071.357143
# TURNS                                  109.285714
# ACTIONS                                176.428571
# STATUES MOVE ONTO SAME SQUARE            1.785714
# TURNCC                                  71.357143
# TIMESTAMP                           577500.000000
# TURNC                                   35.071429
# RESETS                                   1.071429
# MOVES                                   65.500000
# HELP SCREEN ACCESSED                     0.142857
# TOP STATUE EDGE OF BOARD                10.642857
# STATUES BLOCK EACH OTHER                 1.785714
# dtype: float64

# %%
histogram-subsequences
--repeats by player (total num repeated subseq)

1 per player?

number of unique subseq per player

table-avg num times a subseq was repeated per player (low # reps)
                                                      
subseq vs freq hist

# %%
dff = finaldf[0:7].append(finaldf[8:])

# %%
dff
# Out:
#                                  sanorita    nate mylene1 mylene3   josie  \
# PLAYER AND STATUE ON SAME SQUARE        2       2       0       0       8
# MOVES INTO STATUE                       3       5       0       0       3
# BOTTOM STATUE EDGE OF BOARD            13      22       1       6      10
# MOVES OFF BOARD                        15      11       0       0      61
# TIME IN FIRST HELP SCREEN           40000   18000    6000    1000   37000
# TURNS                                 166     179       1      26     152
# ACTIONS                               283     303       3      39     329
# STATUES MOVE ONTO SAME SQUARE           0       5       0       0       1
# TURNCC                                140      45       0      13      63
# HINTS                                   1       1       0       0       2
# TIMESTAMP                          909000  448000   38000   68000  601000
# TURNC                                  26     134       1      13      89
# ...

# %%
print 'MEAN'
dff.mean(axis=1,numeric_only=False)
# Out:
# MEAN
# PLAYER AND STATUE ON SAME SQUARE         2.444444
# MOVES INTO STATUE                        2.722222
# BOTTOM STATUE EDGE OF BOARD             10.666667
# MOVES OFF BOARD                         12.222222
# TIME IN FIRST HELP SCREEN            24499.944444
# TURNS                                  105.888889
# ACTIONS                                183.611111
# STATUES MOVE ONTO SAME SQUARE            1.666667
# TURNCC                                  73.666667
# HINTS                                    1.055556
# TIMESTAMP                           277166.666667
# TURNC                                   29.444444
# RESETS                                   1.777778
# MOVES                                   75.111111
# HELP SCREEN ACCESSED                     0.333333
# TOP STATUE EDGE OF BOARD                10.111111
# STATUES BLOCK EACH OTHER                 0.944444
# dtype: float64

# %%
print 'MEDIAN'
dff.median(axis=1,numeric_only=False)
# Out:
# MEDIAN
# PLAYER AND STATUE ON SAME SQUARE         2.0
# MOVES INTO STATUE                        1.5
# BOTTOM STATUE EDGE OF BOARD             10.0
# MOVES OFF BOARD                          7.5
# TIME IN FIRST HELP SCREEN            14000.0
# TURNS                                   91.0
# ACTIONS                                166.0
# STATUES MOVE ONTO SAME SQUARE            1.0
# TURNCC                                  69.5
# HINTS                                    1.0
# TIMESTAMP                           166500.0
# TURNC                                   19.0
# RESETS                                   1.5
# MOVES                                   77.0
# HELP SCREEN ACCESSED                     0.0
# TOP STATUE EDGE OF BOARD                 8.5
# STATUES BLOCK EACH OTHER                 0.0
# dtype: float64

# %%
print 'MODE'
dff.mode(axis=1,numeric_only=False)
# Out:
# MODE
#                                      0   1   2   3   4
# PLAYER AND STATUE ON SAME SQUARE     0   2 NaN NaN NaN
# MOVES INTO STATUE                    0 NaN NaN NaN NaN
# BOTTOM STATUE EDGE OF BOARD         10 NaN NaN NaN NaN
# MOVES OFF BOARD                      0 NaN NaN NaN NaN
# TIME IN FIRST HELP SCREEN         1000 NaN NaN NaN NaN
# TURNS                               26 NaN NaN NaN NaN
# ACTIONS                            NaN NaN NaN NaN NaN
# STATUES MOVE ONTO SAME SQUARE        0 NaN NaN NaN NaN
# TURNCC                               0 NaN NaN NaN NaN
# HINTS                                1 NaN NaN NaN NaN
# TIMESTAMP                          NaN NaN NaN NaN NaN
# TURNC                                0 NaN NaN NaN NaN
# RESETS                               0 NaN NaN NaN NaN
# MOVES                              NaN NaN NaN NaN NaN
# HELP SCREEN ACCESSED                 0 NaN NaN NaN NaN
# TOP STATUE EDGE OF BOARD             0   2   8  15  16
# ...

# %%
print 'MAX'
dff.max(axis=1,numeric_only=False)
# Out:
# MAX
# PLAYER AND STATUE ON SAME SQUARE         9
# MOVES INTO STATUE                       12
# BOTTOM STATUE EDGE OF BOARD             22
# MOVES OFF BOARD                         61
# TIME IN FIRST HELP SCREEN           148000
# TURNS                                  303
# ACTIONS                                495
# STATUES MOVE ONTO SAME SQUARE            5
# TURNCC                                 245
# HINTS                                    3
# TIMESTAMP                           909000
# TURNC                                  134
# RESETS                                   7
# MOVES                                  183
# HELP SCREEN ACCESSED                     1
# TOP STATUE EDGE OF BOARD                33
# STATUES BLOCK EACH OTHER                 5
# dtype: float64

# %%
print 'MIN'
dff.min(axis=1,numeric_only=False)
# Out:
# MIN
# PLAYER AND STATUE ON SAME SQUARE    0
# MOVES INTO STATUE                   0
# BOTTOM STATUE EDGE OF BOARD         0
# MOVES OFF BOARD                     0
# TIME IN FIRST HELP SCREEN          -1
# TURNS                               0
# ACTIONS                             1
# STATUES MOVE ONTO SAME SQUARE       0
# TURNCC                             -1
# HINTS                               0
# TIMESTAMP                           0
# TURNC                              -1
# RESETS                              0
# MOVES                               0
# HELP SCREEN ACCESSED                0
# TOP STATUE EDGE OF BOARD            0
# STATUES BLOCK EACH OTHER            0
# dtype: float64

# %%
print 'STANDARD DEVIATION'
dff.std(axis=1,numeric_only=False)
# Out:
# STANDARD DEVIATION
# PLAYER AND STATUE ON SAME SQUARE         2.770055
# MOVES INTO STATUE                        3.494627
# BOTTOM STATUE EDGE OF BOARD              6.677442
# MOVES OFF BOARD                         15.175660
# TIME IN FIRST HELP SCREEN            36731.577216
# TURNS                                   79.120823
# ACTIONS                                130.667129
# STATUES MOVE ONTO SAME SQUARE            1.814970
# TURNCC                                  65.249746
# HINTS                                    0.802366
# TIMESTAMP                           257990.024887
# TURNC                                   36.606368
# RESETS                                   1.986885
# MOVES                                   52.618370
# HELP SCREEN ACCESSED                     0.485071
# TOP STATUE EDGE OF BOARD                 8.546681
# STATUES BLOCK EACH OTHER                 1.625974
# dtype: float64

# %%
how to make sense of this data/stats?!
# Out:
#   File "<ipython-input-46-8ad06b249ab2>", line 1
#     how to make sense of this data/stats?!
#          ^
# SyntaxError: invalid syntax
